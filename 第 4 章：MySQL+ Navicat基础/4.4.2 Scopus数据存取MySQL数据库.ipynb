# %%
import pandas as pd
df = pd.read_csv('D:\python科学计量可视化\数据\Demo data\Python-SCOPUS\scopus_1349.csv')
df.head(2)
# Out:
#                       Authors              Author(s) ID  \
# 0  Galickas D., Flaherty G.T.   57420732500;6603837153;
# 1            Yan W., Zhang Y.  56306725200;57200294189;
#
#                                                Title  Year  \
# 0  Is there an association between article citati...  2021
# 1  Participation, academic influences and interac...  2021
#
#                                         Source title Volume Issue Art. No.  \
# 0                         Journal of travel medicine     28     8      NaN
# 1  Canadian Journal of Information and Library Sc...     44   2-3      NaN
#
#   Page start Page end  ...  ISBN  CODEN   PubMed ID  \
# 0        NaN      NaN  ...   NaN    NaN  34414442.0
# 1         31       49  ...   NaN    NaN         NaN
#
#   Language of Original Document Abbreviated Source Title Document Type  \
# 0                       English             J Travel Med       Article
# 1                       English  Can. J. Inf. Libr. Sci.       Article
#
# ...

# %%
from sqlalchemy import create_engine
connect = create_engine('mysql+pymysql://root:123@localhost:3306/')
df.to_sql('scopus',connect,schema='Scientometrics')
# Out:
# 1349

# %%
pd.read_sql_table('scopus',connect,schema='Scientometrics')
# Out:
#       index                                            Authors  \
# 0         0                         Galickas D., Flaherty G.T.
# 1         1                                   Yan W., Zhang Y.
# 2         2        Watson R., Younas A., Rehman S.A., Ali P.A.
# 3         3                      Singh Bajwa S., Mehdiratta L.
# 4         4                Fassoulaki A., Staikou C., Micha G.
# ...     ...                                                ...
# 1344   1344                                       McFedries P.
# 1345   1345                                          Kelley M.
# 1346   1346                                          Taylor M.
# 1347   1347                                          Baynes G.
# 1348   1348  Peters I., Beutelspacher L., Maghferat P., Ter...
#
#                                           Author(s) ID  \
# 0                              57420732500;6603837153;
# 1                             56306725200;57200294189;
# ...
