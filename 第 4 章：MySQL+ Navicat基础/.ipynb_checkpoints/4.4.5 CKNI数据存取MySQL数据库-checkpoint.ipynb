# %%
import pandas as pd
import os,re

# %%
path = 'D:\python科学计量可视化\数据\Demo data\Python-CNKI'

# %%
for file in os.listdir(path):
    abs_path = os.path.join(path,file)
    if '.txt' in abs_path:
        print(abs_path)
# Out:
# D:\python科学计量可视化\数据\Demo data\Python-CNKI\1-500.txt
# D:\python科学计量可视化\数据\Demo data\Python-CNKI\1001-1500.txt
# D:\python科学计量可视化\数据\Demo data\Python-CNKI\1501-2000.txt
# D:\python科学计量可视化\数据\Demo data\Python-CNKI\2001-2037.txt
# D:\python科学计量可视化\数据\Demo data\Python-CNKI\501-1000.txt

# %%
with open(r'D:\python科学计量可视化\数据\Demo data\Python-CNKI\501-1000.txt','r',encoding = 'utf-8') as f:
    txt = f.read()
    ls = txt.split('\n\n')

# %%
len(ls)
# Out:
# 502

# %%
ls[-1]
# Out:
# ''

# %%
ls[-2]
# Out:
# ''

# %%
ls_data = []
for file in os.listdir(path):
    abs_path = os.path.join(path,file)
    if '.txt' in abs_path:
        with open(abs_path,'r',encoding = 'utf-8') as f:
            txt = f.read()
            ls = txt.split('\n\n')[:-2] 
            for j in ls:
                ls_name = []
                dic = {}
                for i in j.split('\n'):   
                    if '%0' in i:
                        dic['Reference Type'] = i[3:]
                    elif '%+' in i:
                        dic['Author Address'] = i[3:]
                    elif '%T' in i:
                        dic['Title'] = i[3:]
                    elif '%A' in i:
                        ls_name.append(i[3:])
                        continue
                    elif '%J' in i:
                        dic['Journal Name'] = i[3:]
                    elif '%D' in i:
                        dic['Year'] = i[3:]
                    elif '%V' in i:
                        dic['Volume'] = i[3:]
                    elif '%N' in i:
                        dic['Number (Issue)'] = i[3:]
                    elif '%K' in i:
                        dic['Keywords'] = i[3:]
                    elif '%X' in i:
                        dic['Abstract'] = i[3:]
                    elif '%P' in i:
                        dic['Pages'] = i[3:]
                    elif '%@' in i:
                        dic['ISBN/ISSN'] = i[3:]
                    elif '%L' in i:
                        dic['Notes'] = i[3:]
                    elif '%U' in i :
                        dic['URL'] = i[3:]
                    elif '%W' in i :
                        dic['Database Provider'] = i[3:]
                    elif '%R' in i :
                        dic['DOI'] = i[3:]
                    dic['Auhor'] = ','.join(ls_name)
                ls_data.append(dic)

# %%
df = pd.DataFrame(ls_data)
df.head()
# Out:
#     Reference Type                           Auhor  \
# 0  Journal Article  张正媚,高宏杰,王梅杰,程亚清,曲海顺,张献之,廖春满,李靖
# 1  Journal Article                      党真,杨明义,张加琼
# 2  Journal Article                         王丽霞,邓晓雅
# 3  Journal Article                    张茜,蔺楠,倪梦媛,周炜
# 4  Journal Article               阚越,章锦河,李湮,王培家,曹姗姗
#
#                                       Author Address  \
# 0  北京中医药大学东直门医院;中国中医科学院中医药信息研究所;北京中医药大学东方医院;广西壮族自...
# 1  中国科学院水利部水土保持研究所黄土高原土壤侵蚀与旱地农业国家重点实验室;中国科学院大学;西北...
# 2                                        华侨大学国际关系学院;
# 3                                         上海财经大学商学院;
# 4                     南京大学地理与海洋科学学院;伊犁师范大学旅游与历史文化学院;
#
#                                    Title     Journal Name  \
# 0    基于VOSviewer和CiteSpace的白芍总苷研究热点可视化分析        中国中医药信息杂志
# 1                   基于文献计量学分析泥沙来源研究进展与热点           水土保持研究
# 2  我国华侨华人研究的可视化分析——基于CSSCI(1999—2020年)数据  华侨大学学报(哲学社会科学版)
# 3                  性别视角下的创业企业融资绩效研究回顾与展望          研究与发展管理
# ...

# %%
def cnki_to_df(folder_path):
    import pandas as pd
    import os
    ls_data = []
    for file in os.listdir(folder_path):
        abs_path = os.path.join(folder_path,file)
        if '.txt' in abs_path:
            with open(abs_path,'r',encoding = 'utf-8') as f:
                txt = f.read()
                ls = txt.replace('\n\n','').split('%0')[1:]    
                for j in ls:
                    ls_name = []
                    dic = {}
                    for i in j.split('\n'):   
                        if i.startswith(' '):
                            dic['Reference Type'] = i[1:] 
                        elif '%+' in i:
                            dic['Author Address'] = i[3:]
                        elif '%T' in i:
                            dic['Title'] = i[3:]
                        elif '%A' in i:
                            ls_name.append(i[3:])
                            continue
                        elif '%J' in i:
                            dic['Journal Name'] = i[3:]
                        elif '%D' in i:
                            dic['Year'] = i[3:]
                        elif '%V' in i:
                            dic['Volume'] = i[3:]
                        elif '%N' in i:
                            dic['Number (Issue)'] = i[3:]
                        elif '%K' in i:
                            dic['Keywords'] = i[3:]
                        elif '%X' in i:
                            dic['Abstract'] = i[3:]
                        elif '%P' in i:
                            dic['Pages'] = i[3:]
                        elif '%@' in i:
                            dic['ISBN/ISSN'] = i[3:]
                        elif '%L' in i:
                            dic['Notes'] = i[3:]
                        elif '%U' in i :
                            dic['URL'] = i[3:]
                        elif '%W' in i :
                            dic['Database Provider'] = i[3:]
                        elif '%R' in i :
                            dic['DOI'] = i[3:]
                        dic['Author'] = ','.join(ls_name)
                    ls_data.append(dic)
    return pd.DataFrame(ls_data)

# %%
folder_path = 'D:\python科学计量可视化\数据\Demo data\Python-CNKI'
cnki_to_df(folder_path).head(2)
# Out:
#     Reference Type                           Auhor  \
# 0  Journal Article  张正媚,高宏杰,王梅杰,程亚清,曲海顺,张献之,廖春满,李靖
# 1  Journal Article                      党真,杨明义,张加琼
#
#                                       Author Address  \
# 0  北京中医药大学东直门医院;中国中医科学院中医药信息研究所;北京中医药大学东方医院;广西壮族自...
# 1  中国科学院水利部水土保持研究所黄土高原土壤侵蚀与旱地农业国家重点实验室;中国科学院大学;西北...
#
#                                  Title Journal Name  \
# 0  基于VOSviewer和CiteSpace的白芍总苷研究热点可视化分析    中国中医药信息杂志
# 1                 基于文献计量学分析泥沙来源研究进展与热点       水土保持研究
#
#                            Keywords  \
# 0    白芍总苷;VOSviewer;CiteSpace;可视化分析
# 1  泥沙来源;土壤侵蚀;可视化分析;CiteSpace;复合指纹识别
#
#                                             Abstract Pages  ISBN/ISSN  \
# 0  目的分析白芍总苷研究现状和热点，为白芍总苷研究与应用提供参考。方法计算机检索中国知识资源总库...   1-7  1005-5304
# 1  明确流域或区域泥沙来源对水土保持措施科学布局有重要意义。为了更好地掌握泥沙来源研究的发展动态...   1-6  1005-3409
#
#        Notes                                                URL  \
# 0  11-3519/R  https://kns.cnki.net/kcms/detail/11.3519.R.202...
# ...

# %%
len(cnki_to_df(folder_path))
# Out:
# 2037

# %%
df = cnki_to_df(folder_path)

# %%
from sqlalchemy import create_engine
connect = create_engine('mysql+pymysql://root:123@localhost:3306/')
df.to_sql('cnki',connect,schema='Scientometrics')
# Out:
# 2037

# %%
import pandas as pd
pd.read_sql_table('cnki',connect,schema='Scientometrics')
# Out:
#       index   Reference Type                           Auhor  \
# 0         0  Journal Article  张正媚,高宏杰,王梅杰,程亚清,曲海顺,张献之,廖春满,李靖
# 1         1  Journal Article                      党真,杨明义,张加琼
# 2         2  Journal Article                         王丽霞,邓晓雅
# 3         3  Journal Article                    张茜,蔺楠,倪梦媛,周炜
# 4         4  Journal Article               阚越,章锦河,李湮,王培家,曹姗姗
# ...     ...              ...                             ...
# 2032   2032  Journal Article                          孟宇,陈坚林
# 2033   2033  Journal Article                      李凤侠,张俊,赵呈刚
# 2034   2034  Journal Article                         高珂晓,赵彩云
# 2035   2035  Journal Article                      池仁勇,廖雅雅,王昀
# 2036   2036  Journal Article              张增可,王齐,吴雅华,刘兴诏,黄柳菁
#
#                                          Author Address  \
# 0     北京中医药大学东直门医院;中国中医科学院中医药信息研究所;北京中医药大学东方医院;广西壮族自...
# 1     中国科学院水利部水土保持研究所黄土高原土壤侵蚀与旱地农业国家重点实验室;中国科学院大学;西北...
# 2                                           华侨大学国际关系学院;
# ...
