# %%
# !pip install pandas==1.4.1
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
# !pip install sqlalchemy==1.4.32
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
import pandas as pd
import metaknowledge as mk

# %% [markdown]
# 注意：RecordCollection()括号中填写用户数据放置的地址

# %%
RC = mk.RecordCollection('D:\python科学计量可视化\数据\Demo data\Python-Wos')
RC
# Out:
# <metaknowledge.RecordCollection object files-from-D:\python科学计量可视化\数据\Demo data\Python-Wos>

# %%
df = pd.DataFrame(RC.makeDict())
df.head(3)
# Out:
#   PT                                                 AU  \
# 0  J                               [Zhou, P, Zhong, YF]
# 1  J                     [Huang, Y, Chen, LX, Zhang, L]
# 2  J  [Birnholtz, J, Guha, S, Yuan, YC, Gay, G, Hell...
#
#                                                   AF  \
# 0                      [Zhou, Ping, Zhong, Yongfeng]
# 1             [Huang, Ying, Chen, Lixin, Zhang, Lin]
# 2  [Birnholtz, Jeremy, Guha, Shion, Yuan, Y. Conn...
#
#                                                   TI  \
# 0  The citation-based indicator and combined impa...
# 1  Patent citation inflation: The phenomenon, its...
# 2  Cross-campus collaboration: A scientometric an...
#
#                                                   SO       LA       DT  \
# 0                            JOURNAL OF INFORMETRICS  English  Article
# 1                            JOURNAL OF INFORMETRICS  English  Article
# 2  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...  English  Article
#
# ...

# %%
from sqlalchemy import create_engine
connect = create_engine('mysql+pymysql://root:123@localhost:3306/')
df.to_sql('wos',connect,schema='Scientometrics',if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c5f04393272c> in <module>
#       1 from sqlalchemy import create_engine
#       2 connect = create_engine('mysql+pymysql://root:123@localhost:3306/')
# ----> 3 df.to_sql('wos',connect,schema='Scientometrics',if_exists='append')
#
# D:\miniconda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2961         from pandas.io import sql
#    2962
# -> 2963         return sql.to_sql(
#    2964             self,
#    2965             name,
#
# D:\miniconda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     695         )
#     696
# --> 697     return pandas_sql.to_sql(
#     698         frame,
#     699         name,
#
# ...

# %%
for i in range(len(df.columns)):
    df.iloc[:,i] = df.iloc[:,i].astype(str)

# %%
from sqlalchemy import create_engine
connect = create_engine('mysql+pymysql://root:123@localhost:3306/')
df.to_sql('wos',connect,schema='Scientometrics')
# Out:
# 6358

# %%
pd.read_sql_table('wos',connect,schema='Scientometrics')
# Out:
#       index PT                                                 AU  \
# 0         0  J                           ['Zhou, P', 'Zhong, YF']
# 1         1  J               ['Huang, Y', 'Chen, LX', 'Zhang, L']
# 2         2  J  ['Birnholtz, J', 'Guha, S', 'Yuan, YC', 'Gay, ...
# 3         3  J                 ['Zhai, YJ', 'Ding, Y', 'Wang, F']
# 4         4  J                                    ['Schubert, A']
# ...     ... ..                                                ...
# 6353   6353  J                  ['Liu, X', 'Jiang, TT', 'Ma, FC']
# 6354   6354  J    ['Lee, LC', 'Lin, PH', 'Chuang, YW', 'Lee, YY']
# 6355   6355  J                            ['Swar, B', 'Khan, GF']
# 6356   6356  J  ['Ibarra, ME', 'Ferreira, JP', 'Torrents, M', ...
# 6357   6357  J                    ['Harzing, AW', 'Alakangas, S']
#
#                                                      AF  \
# 0                     ['Zhou, Ping', 'Zhong, Yongfeng']
# 1          ['Huang, Ying', 'Chen, Lixin', 'Zhang, Lin']
# ...

# %%
df.columns
# Out:
# Index(['PT', 'AU', 'AF', 'TI', 'SO', 'LA', 'DT', 'DE', 'AB', 'C1', 'RP', 'EM',
#        'RI', 'OI', 'CR', 'NR', 'TC', 'Z9', 'U1', 'U2', 'PU', 'PI', 'PA', 'SN',
#        'EI', 'J9', 'JI', 'PD', 'PY', 'VL', 'IS', 'BP', 'EP', 'DI', 'PG', 'WC',
#        'SC', 'GA', 'UT', 'OA', 'DA', 'ID', 'FU', 'FX', 'AR', 'EA', 'CT', 'CY',
#        'CL', 'SP', 'HO', 'PM', 'SI', 'HC', 'HP', 'num-Authors', 'num-Male',
#        'num-Female', 'num-Unknown'],
#       dtype='object')
