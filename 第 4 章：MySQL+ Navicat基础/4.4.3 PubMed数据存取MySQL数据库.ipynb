# %%
import pandas as pd
import metaknowledge as mk

# %%
RC = mk.RecordCollection(r'D:\python科学计量可视化\数据\Demo data\Python-PubMed')
RC
# Out:
# <metaknowledge.RecordCollection object files-from-D:\python科学计量可视化\数据\Demo data\Python-PubMed>

# %%
df = pd.DataFrame(RC.makeDict())
df.head(3)
# Out:
#             PMID    OWN       STAT        DCOM          LR  \
# 0  PMID:30518809  [NLM]  [MEDLINE]  [20200626]  [20210109]
# 1  PMID:25403604  [NLM]  [MEDLINE]  [20150305]  [20181202]
# 2  PMID:28597796  [NLM]  [MEDLINE]  [20190628]  [20190718]
#
#                                               IS  VI   IP        DP  \
# 0  [1476-5527 (Electronic), 0950-9240 (Linking)]  33  [3]  2019 Mar
# 1  [1524-4563 (Electronic), 0194-911X (Linking)]  65  [2]  2015 Feb
# 2       [0001-5385 (Print), 0001-5385 (Linking)]  72  [2]  2017 Apr
#
#                                                   TI  ...   OID  PMCR   RIN  \
# 0  A systematic review and network meta-analysis ...  ...  None  None  None
# 1  Magnitude of blood pressure reduction in the p...  ...  None  None  None
# 2  A1166C polymorphism of the angiotensin II type...  ...  None  None  None
#
#     OAB  OABL   RPI num-Authors num-Male num-Female num-Unknown
# 0  None  None  None           7        3          4           0
# ...

# %%
for i in range(len(df.columns)):
    df.iloc[:,i] = df.iloc[:,i].astype(str)

# %%
from sqlalchemy import create_engine
connect = create_engine('mysql+pymysql://root:123@localhost:3306/')
df.to_sql('pubmed',connect,schema='Scientometrics')
# Out:
# 2000

# %%
pd.read_sql_table('pubmed',connect,schema='Scientometrics')
# Out:
#       index           PMID      OWN         STAT          DCOM            LR  \
# 0         0  PMID:30518809  ['NLM']  ['MEDLINE']  ['20200626']  ['20210109']
# 1         1  PMID:25403604  ['NLM']  ['MEDLINE']  ['20150305']  ['20181202']
# 2         2  PMID:28597796  ['NLM']  ['MEDLINE']  ['20190628']  ['20190718']
# 3         3  PMID:22331252  ['NLM']  ['MEDLINE']  ['20160423']  ['20211021']
# 4         4  PMID:29318704  ['NLM']  ['MEDLINE']  ['20190909']  ['20190909']
# ...     ...            ...      ...          ...           ...           ...
# 1995   1995  PMID:28411166  ['NLM']  ['MEDLINE']  ['20171023']  ['20181202']
# 1996   1996  PMID:29134444  ['NLM']  ['MEDLINE']  ['20180813']  ['20181113']
# 1997   1997  PMID:29899980  ['NLM']  ['MEDLINE']  ['20180619']  ['20181202']
# 1998   1998  PMID:32888198  ['NLM']  ['MEDLINE']  ['20201019']  ['20210906']
# 1999   1999  PMID:29973178  ['NLM']  ['MEDLINE']  ['20190321']  ['20190610']
#
# ...
