# %%
'Python'+'科学计量'
# Out:
# 'Python科学计量'

# %%
import matplotlib.pyplot as plt #导入模块，为了方便调用，另起一个简单的别名

x = [1,2,3,4]                   #设置x数据
y = [5,6,7,8]                   #设置y数据

plt.plot(x,y)                   #绘制图形
plt.show()                      #显示图形

# %%
import matplotlib
print('matplotlib的版本号：',matplotlib.__version__)
print('matplotlib的路径位于',matplotlib.__path__)
# Out:
# matplotlib的版本号： 3.8.0
# matplotlib的路径位于 ['D:\\Data Science\\BI\\Bliometrics\\bliometrics\\lib\\site-packages\\matplotlib']

# %% [markdown]
# ## 第三方模块的安装

# %% [markdown]
#     安装指令： pip install <model_name>
#     检验指令： import <model_name>

# %% [markdown]
# 比如安装metaknowledge模块：
#
#     pip install metaknowledge

# %% [markdown]
# 如果下载网络不稳定，或者下载的第三方模块体积较大，可以添加镜像进行安装，比如使用清华大学的镜像安装
#
#     pip install <model_name> -i https://pypi.tuna.tsinghua.edu.cn/simple/

# %%
pip install -i https://pypi.tuna.tsinghua.edu.cn/simple/ pandas matplotlib metaknowledge plotly pyecharts jupyter chart_studio seaborn cntext networkx python-louvain
